# %%
# !pip install git+https://github.com/PrithivirajDamodaran/Styleformer.git
# Out:
# Collecting git+https://github.com/PrithivirajDamodaran/Styleformer.git
#   Cloning https://github.com/PrithivirajDamodaran/Styleformer.git to /tmp/pip-req-build-0dscbboe
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Styleformer.git /tmp/pip-req-build-0dscbboe
# Collecting transformers
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 4.7 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 50.1 MB/s
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 5.4 MB/s
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->styleformer==0.1) (57.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (1.21.5)
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 37.6 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.7 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 48.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (3.4.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer==0.1) (4.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers->styleformer==0.1) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->styleformer==0.1) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->styleformer==0.1) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer==0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer==0.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer==0.1) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer==0.1) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer==0.1) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer==0.1) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer==0.1) (1.15.0)
# Building wheels for collected packages: styleformer, python-Levenshtein
#   Building wheel for styleformer (setup.py) ... done
#   Created wheel for styleformer: filename=styleformer-0.1-py3-none-any.whl size=8620 sha256=1797f9e96079d5b4ab6f3664f72bdf523031dc11deaaa70c81303b0bcfedfe0c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_rkl0yq8/wheels/85/3e/e9/5f30f549b352fb24bdc7287b0bf59f78de70af14090d336be0
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149865 sha256=1ae38931d5a18c7e61051626318fa8fef76f046b86b47d6f3081764072b5bc30
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built styleformer python-Levenshtein
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, python-Levenshtein, fuzzywuzzy, styleformer
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed fuzzywuzzy-0.18.0 huggingface-hub-0.4.0 python-Levenshtein-0.12.2 pyyaml-6.0 sacremoses-0.0.47 sentencepiece-0.1.96 styleformer-0.1 tokenizers-0.11.5 transformers-4.16.2

# %%
from styleformer import Styleformer
import warnings
warnings.filterwarnings("ignore")

# style = [0=Casual to Formal, 1=Formal to Casual, 2=Active to Passive, 3=Passive to Active etc..]
sf = Styleformer(style = 1) 
import torch
def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(1212)

source_sentences = [
"I would love to meet attractive men in town",
"Please leave the room now",
"It is a delicious icecream",
"I am not paying this kind of money for that nonsense",
"He is on cocaine and he cannot be trusted with this",
"He is a very nice man and has a charming personality",
"Let us go out for dinner",
"We went to Barcelona for the weekend. We have a lot of things to tell you.",
]   

for source_sentence in source_sentences:
    # inference_on = [0=Regular model On CPU, 1= Regular model On GPU, 2=Quantized model On CPU]
    target_sentence = sf.transfer(source_sentence, inference_on=0, quality_filter=0.95, max_candidates=5)
    print("[Formal] ", source_sentence)
    if target_sentence is not None:
        print("[Casual] ",target_sentence)
    else:
        print("No good quality transfers available !")
    print("-" *100)
# Out:
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Formal to Casual model loaded...
# [Formal]  I would love to meet attractive men in town
# [Casual]  I'd love to meet sexy guys in town
# ----------------------------------------------------------------------------------------------------
# [Formal]  Please leave the room now
# [Casual]  please break out of the room now
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is a delicious icecream
# [Casual]  a yummy icecream
# ----------------------------------------------------------------------------------------------------
# [Formal]  I am not paying this kind of money for that nonsense
# [Casual]  I'm not paying this kind of money for that nonsense
# ----------------------------------------------------------------------------------------------------
# [Formal]  He is on cocaine and he cannot be trusted with this
# [Casual]  he's on coke and can't be trusted with this.
# ----------------------------------------------------------------------------------------------------
# [Formal]  He is a very nice man and has a charming personality
# [Casual]  I think he is just a nice guy with a lovely personality.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Let us go out for dinner
# [Casual]  and so if you want to eat dinner in general, then i'd go out with you for dinner
# ----------------------------------------------------------------------------------------------------
# [Formal]  We went to Barcelona for the weekend. We have a lot of things to tell you.
# [Casual]  We went to Barcelona on the weekend and we have alot to tell you.
# ----------------------------------------------------------------------------------------------------

# %%
from styleformer import Styleformer
import torch
import warnings
warnings.filterwarnings("ignore")

'''
#uncomment for re-producability
def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(1234)
'''

# style = [0=Casual to Formal, 1=Formal to Casual, 2=Active to Passive, 3=Passive to Active etc..]
sf = Styleformer(style = 0) 

source_sentences = [
"I am quitting my job",
"Jimmy is on crack and can't trust him",
"What do guys do to show that they like a gal?",
"i loooooooooooooooooooooooove going to the movies.",
"That movie was fucking awesome",
"My mom is doing fine",
"That was funny LOL" , 
"It's piece of cake, we can do it",
"btw - ur avatar looks familiar",
"who gives a crap?",
"Howdy Lucy! been ages since we last met.",
"Dude, this car's dope!",
"She's my bestie from college",
"I kinda have a feeling that he has a crush on you.",
"OMG! It's finger-lickin' good.",
]   

for source_sentence in source_sentences:
    target_sentence = sf.transfer(source_sentence)
    print("-" *100)
    print("[Casual] ", source_sentence)
    print("-" *100)
    if target_sentence is not None:
        print("[Formal] ",target_sentence)
        print()
    else:
        print("No good quality transfers available !")
# Out:
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Casual to Formal model loaded...
# ----------------------------------------------------------------------------------------------------
# [Casual]  I am quitting my job
# ----------------------------------------------------------------------------------------------------
# [Formal]  I am leaving my job.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jimmy is on crack and can't trust him
# ----------------------------------------------------------------------------------------------------
# [Formal]  Jimmy is addicted and I cannot trust him.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  What do guys do to show that they like a gal?
# ----------------------------------------------------------------------------------------------------
# [Formal]  What do men do to prove their love for a female?
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  i loooooooooooooooooooooooove going to the movies.
# ----------------------------------------------------------------------------------------------------
# [Formal]  I absolutely enjoy going to the movies.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  That movie was fucking awesome
# ----------------------------------------------------------------------------------------------------
# [Formal]  The movie was great.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  My mom is doing fine
# ----------------------------------------------------------------------------------------------------
# [Formal]  My mother is doing well.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  That was funny LOL
# ----------------------------------------------------------------------------------------------------
# [Formal]  I found that humorous.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  It's piece of cake, we can do it
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is very easy, we will do it.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  btw - ur avatar looks familiar
# ----------------------------------------------------------------------------------------------------
# [Formal]  By the way, your avatar looks familiar.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  who gives a crap?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Who cares?
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  Howdy Lucy! been ages since we last met.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Hello Lucy, it has been a long time since we last met.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  Dude, this car's dope!
# ----------------------------------------------------------------------------------------------------
# [Formal]  This car is fantastic.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  She's my bestie from college
# ----------------------------------------------------------------------------------------------------
# [Formal]  She is my best friend since college.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  I kinda have a feeling that he has a crush on you.
# ----------------------------------------------------------------------------------------------------
# [Formal]  It seems that he has an opinion regarding you.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]  OMG! It's finger-lickin' good.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Oh my goodness, it's good.
